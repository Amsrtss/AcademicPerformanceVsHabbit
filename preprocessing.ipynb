# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load dataset
df = pd.read_csv('data.csv')

#Print fist 5 row
df.head(5)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
# Ambil hanya kolom numerik
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Buat heatmap korelasi
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
p = scatter_matrix(df, figsize=(25, 25))

# %%
# Buat figure besar untuk banyak subplot
plt.figure(figsize=(15, 10))

# Ambil semua kolom numerik
num_cols = df.select_dtypes(include=['number']).columns

# Loop untuk membuat subplot histogram distribusi tiap kolom
for i, col in enumerate(num_cols, 1):
    plt.subplot(len(num_cols)//3 + 1, 3, i)  # grid 3 kolom, baris menyesuaikan
    sns.histplot(df[col], kde=True)  # histogram + KDE (kurva distribusi)
    plt.title(f'Distribusi {col}')

plt.tight_layout()
plt.show()

# %%
print(df.isnull().sum())
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))
    return outliers.sum()

print("\nOutlier per Kolom Numerik:")
for col in df.select_dtypes(include=['number']).columns:
    print(f"{col}: {detect_outliers_iqr(df[col])}")
# Out:
# Outlier per Kolom Numerik:
# age: 0
# study_hours_per_day: 7
# social_media_hours: 5
# netflix_hours: 4
# attendance_percentage: 3
# sleep_hours: 2
# exercise_frequency: 0
# mental_health_rating: 0
# exam_score: 2

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df.part_time_job.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.diet_quality.unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
df.parental_education_level.unique()
# Out:
# array(['Master', 'High School', 'Bachelor', nan], dtype=object)

# %%
df.internet_quality.unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
df.extracurricular_participation.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.isnull()
# Out:
#      student_id    age  gender  study_hours_per_day  social_media_hours  \
# 0         False  False   False                False               False
# 1         False  False   False                False               False
# 2         False  False   False                False               False
# 3         False  False   False                False               False
# 4         False  False   False                False               False
# ..          ...    ...     ...                  ...                 ...
# 995       False  False   False                False               False
# 996       False  False   False                False               False
# 997       False  False   False                False               False
# 998       False  False   False                False               False
# 999       False  False   False                False               False
#
#      netflix_hours  part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df[df['parental_education_level'].isna()]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 10       S1010   19  Female                  4.6                 3.7
# 33       S1033   18  Female                  4.0                 0.9
# 47       S1047   23  Female                  2.5                 2.9
# 74       S1074   21  Female                  2.3                 1.0
# 93       S1093   22    Male                  4.1                 2.5
# ..         ...  ...     ...                  ...                 ...
# 921      S1921   23  Female                  4.4                 2.7
# 925      S1925   19   Other                  1.7                 2.9
# 939      S1939   18  Female                  4.7                 3.2
# 945      S1945   23    Male                  6.0                 2.9
# 967      S1967   22    Male                  5.2                 4.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df = df.dropna(subset=['parental_education_level'])

# %%
print(df.shape)
# Out:
# (909, 16)

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
# Salin df 
df_encoded = df.copy()

df_encoded = df_encoded.drop(columns=['student_id'])

# Label Encoding manual untuk kolom ORDINAL
# Diet Quality
diet_quality_mapping = {'Poor': 0, 'Fair': 1, 'Good': 2}
df_encoded['diet_quality'] = df_encoded['diet_quality'].map(diet_quality_mapping)

# Parental Education Level
parental_education_mapping = {
    'High School': 0,
    'Bachelor': 1,
    'Master': 2,
    'PhD': 3
}
df_encoded['parental_education_level'] = df_encoded['parental_education_level'].map(parental_education_mapping)

# Internet Quality
internet_quality_mapping = {'Poor': 0, 'Average': 1, 'Good': 2}
df_encoded['internet_quality'] = df_encoded['internet_quality'].map(internet_quality_mapping)

# One Hot Encoding untuk kolom NOMINAL
nominal_cols = ['gender', 'part_time_job', 'extracurricular_participation']
df_encoded = pd.get_dummies(df_encoded, columns=nominal_cols, drop_first=True)  # drop_first=True → biar ga dummy trap

# Cek hasil
print(df_encoded.head())
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  diet_quality  exercise_frequency  \
# 0                   85.0          8.0             1                   6
# 1                   97.3          4.6             2                   6
# 2                   94.8          8.0             0                   1
# 3                   71.0          9.2             0                   4
# 4                   90.9          4.9             1                   3
#
#    parental_education_level  internet_quality  mental_health_rating  \
# 0                         2                 1                     8
# ...

# %%
df_encoded.to_csv("df_encoded.csv", index=False)
